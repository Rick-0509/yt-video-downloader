# %% [markdown]
# ### DESCARGAR VIDEOS E YOUTUBE

# %%
pip install yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in c:\users\propietario\anaconda3\lib\site-packages (2026.3.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yt_dlp

def descargar_video(url, carpeta_destino="."):
    opciones = {
        'outtmpl': f'{carpeta_destino}/%(title)s.%(ext)s',
        'format': 'best[ext=mp4]/best',  # ✅ Mejor calidad en UN solo archivo, sin necesitar FFmpeg
        'noplaylist': True,
    }

    with yt_dlp.YoutubeDL(opciones) as ydl:
        info = ydl.extract_info(url, download=False)
        print(f"🎬 Título    : {info['title']}")
        print(f"📺 Resolución: {info.get('height', 'N/A')}p")
        print("⬇️  Descargando...\n")
        ydl.download([url])
        print("✅ Descarga completada!")

descargar_video("https://www.youtube.com/watch?v=fmZ54ziDlf0&list=RDfmZ54ziDlf0&start_radio=1")
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=fmZ54ziDlf0&list=RDfmZ54ziDlf0&start_radio=1
# [youtube:tab] Downloading just the video fmZ54ziDlf0 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fmZ54ziDlf0
# [youtube] fmZ54ziDlf0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] fmZ54ziDlf0: Downloading android vr player API JSON
# 🎬 Título    : Igual Que Ayer
# 📺 Resolución: 360p
# ⬇️  Descargando...
#
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=fmZ54ziDlf0&list=RDfmZ54ziDlf0&start_radio=1
# [youtube:tab] Downloading just the video fmZ54ziDlf0 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fmZ54ziDlf0
# [youtube] fmZ54ziDlf0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] fmZ54ziDlf0: Downloading android vr player API JSON
# [info] fmZ54ziDlf0: Downloading 1 format(s): 18
# [download] Destination: Igual Que Ayer.mp4
# [download] 100% of    2.55MiB in 00:00:00 at 37.79MiB/s
# ✅ Descarga completada!
